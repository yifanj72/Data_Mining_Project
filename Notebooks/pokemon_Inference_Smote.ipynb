# %%
import pandas as pd
import numpy as np

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score



from sklearn.metrics import roc_curve, auc

pd.set_option('display.max_columns', None)

# %%
#drop base_egg_steps
#binning experience growth, capture rate
pokemon = pd.read_csv('pokemon_bin_1.csv')
pokemon.head()
# Out:
#    against_bug  against_dark  against_dragon  against_electric  against_fairy  \
# 0          1.0           1.0             1.0               0.5            0.5
# 1          1.0           1.0             1.0               0.5            0.5
# 2          1.0           1.0             1.0               0.5            0.5
# 3          0.5           1.0             1.0               1.0            0.5
# 4          0.5           1.0             1.0               1.0            0.5
#
#    against_fight  against_fire  against_flying  against_ghost  against_grass  \
# 0            0.5           2.0             2.0            1.0           0.25
# 1            0.5           2.0             2.0            1.0           0.25
# 2            0.5           2.0             2.0            1.0           0.25
# 3            1.0           0.5             1.0            1.0           0.50
# 4            1.0           0.5             1.0            1.0           0.50
#
#    against_ground  against_ice  against_normal  against_poison  \
# 0             1.0          2.0             1.0             1.0
# 1             1.0          2.0             1.0             1.0
# 2             1.0          2.0             1.0             1.0
# 3             2.0          0.5             1.0             1.0
# 4             2.0          0.5             1.0             1.0
#
#    against_psychic  against_rock  against_steel  against_water  attack  \
# 0              2.0           1.0            1.0            0.5      49
# 1              2.0           1.0            1.0            0.5      62
# 2              2.0           1.0            1.0            0.5     100
# 3              1.0           2.0            0.5            2.0      52
# 4              1.0           2.0            0.5            2.0      64
#
#    base_happiness  base_total  defense  height_m  hp        name  sp_attack  \
# 0              70         318       49       0.7  45   Bulbasaur         65
# 1              70         405       63       1.0  60     Ivysaur         80
# 2              70         625      123       2.0  80    Venusaur        122
# 3              70         309       43       0.6  39  Charmander         60
# 4              70         405       58       1.1  58  Charmeleon         80
#
#    sp_defense  speed  type1   type2  weight_kg  is_legendary capture_rate_bin  \
# 0          65     45  grass  poison        6.9             0            0-0.5
# 1          80     60  grass  poison       13.0             0            0-0.5
# 2         120     80  grass  poison      100.0             0            0-0.5
# 3          50     65   fire    none        8.5             0            0-0.5
# 4          65     80   fire    none       19.0             0            0-0.5
#
#   experience_growth_bin
# 0            Below 1.1M
# 1            Below 1.1M
# 2            Below 1.1M
# 3            Below 1.1M
# 4            Below 1.1M

# %%
pokemon.isnull().sum()
# Out:
# against_bug              0
# against_dark             0
# against_dragon           0
# against_electric         0
# against_fairy            0
# against_fight            0
# against_fire             0
# against_flying           0
# against_ghost            0
# against_grass            0
# against_ground           0
# against_ice              0
# against_normal           0
# against_poison           0
# against_psychic          0
# against_rock             0
# against_steel            0
# against_water            0
# attack                   0
# base_happiness           0
# base_total               0
# defense                  0
# height_m                 0
# hp                       0
# name                     0
# sp_attack                0
# sp_defense               0
# speed                    0
# type1                    0
# type2                    0
# weight_kg                0
# is_legendary             0
# capture_rate_bin         0
# experience_growth_bin    0
# dtype: int64

# %%
pokemon = pokemon.set_index('name')
pokemon.head()
# Out:
#             against_bug  against_dark  against_dragon  against_electric  \
# name
# Bulbasaur           1.0           1.0             1.0               0.5
# Ivysaur             1.0           1.0             1.0               0.5
# Venusaur            1.0           1.0             1.0               0.5
# Charmander          0.5           1.0             1.0               1.0
# Charmeleon          0.5           1.0             1.0               1.0
#
#             against_fairy  against_fight  against_fire  against_flying  \
# name
# Bulbasaur             0.5            0.5           2.0             2.0
# Ivysaur               0.5            0.5           2.0             2.0
# Venusaur              0.5            0.5           2.0             2.0
# Charmander            0.5            1.0           0.5             1.0
# Charmeleon            0.5            1.0           0.5             1.0
#
#             against_ghost  against_grass  against_ground  against_ice  \
# name
# Bulbasaur             1.0           0.25             1.0          2.0
# Ivysaur               1.0           0.25             1.0          2.0
# Venusaur              1.0           0.25             1.0          2.0
# Charmander            1.0           0.50             2.0          0.5
# Charmeleon            1.0           0.50             2.0          0.5
#
#             against_normal  against_poison  against_psychic  against_rock  \
# name
# Bulbasaur              1.0             1.0              2.0           1.0
# Ivysaur                1.0             1.0              2.0           1.0
# Venusaur               1.0             1.0              2.0           1.0
# Charmander             1.0             1.0              1.0           2.0
# Charmeleon             1.0             1.0              1.0           2.0
#
#             against_steel  against_water  attack  base_happiness  base_total  \
# name
# Bulbasaur             1.0            0.5      49              70         318
# Ivysaur               1.0            0.5      62              70         405
# Venusaur              1.0            0.5     100              70         625
# Charmander            0.5            2.0      52              70         309
# Charmeleon            0.5            2.0      64              70         405
#
#             defense  height_m  hp  sp_attack  sp_defense  speed  type1  \
# name
# Bulbasaur        49       0.7  45         65          65     45  grass
# Ivysaur          63       1.0  60         80          80     60  grass
# Venusaur        123       2.0  80        122         120     80  grass
# Charmander       43       0.6  39         60          50     65   fire
# Charmeleon       58       1.1  58         80          65     80   fire
#
#              type2  weight_kg  is_legendary capture_rate_bin  \
# name
# Bulbasaur   poison        6.9             0            0-0.5
# Ivysaur     poison       13.0             0            0-0.5
# Venusaur    poison      100.0             0            0-0.5
# Charmander    none        8.5             0            0-0.5
# Charmeleon    none       19.0             0            0-0.5
#
#            experience_growth_bin
# name
# Bulbasaur             Below 1.1M
# Ivysaur               Below 1.1M
# Venusaur              Below 1.1M
# Charmander            Below 1.1M
# Charmeleon            Below 1.1M

# %%
df = pd.get_dummies(pokemon)

# %%
df
# Out:
#             against_bug  against_dark  against_dragon  against_electric  \
# name
# Bulbasaur          1.00           1.0             1.0               0.5
# Ivysaur            1.00           1.0             1.0               0.5
# Venusaur           1.00           1.0             1.0               0.5
# Charmander         0.50           1.0             1.0               1.0
# Charmeleon         0.50           1.0             1.0               1.0
# ...                 ...           ...             ...               ...
# Celesteela         0.25           1.0             0.5               2.0
# Kartana            1.00           1.0             0.5               0.5
# Guzzlord           2.00           0.5             2.0               0.5
# Necrozma           2.00           2.0             1.0               1.0
# Magearna           0.25           0.5             0.0               1.0
#
#             against_fairy  against_fight  against_fire  against_flying  \
# name
# Bulbasaur             0.5            0.5           2.0             2.0
# Ivysaur               0.5            0.5           2.0             2.0
# Venusaur              0.5            0.5           2.0             2.0
# Charmander            0.5            1.0           0.5             1.0
# Charmeleon            0.5            1.0           0.5             1.0
# ...                   ...            ...           ...             ...
# Celesteela            0.5            1.0           2.0             0.5
# Kartana               0.5            2.0           4.0             1.0
# Guzzlord              4.0            2.0           0.5             1.0
# Necrozma              1.0            0.5           1.0             1.0
# Magearna              0.5            1.0           2.0             0.5
#
#             against_ghost  against_grass  against_ground  against_ice  \
# name
# Bulbasaur             1.0           0.25             1.0          2.0
# Ivysaur               1.0           0.25             1.0          2.0
# Venusaur              1.0           0.25             1.0          2.0
# Charmander            1.0           0.50             2.0          0.5
# Charmeleon            1.0           0.50             2.0          0.5
# ...                   ...            ...             ...          ...
# Celesteela            1.0           0.25             0.0          1.0
# Kartana               1.0           0.25             1.0          1.0
# Guzzlord              0.5           0.50             1.0          2.0
# Necrozma              2.0           1.00             1.0          1.0
# Magearna              1.0           0.50             2.0          0.5
#
#             against_normal  against_poison  against_psychic  against_rock  \
# name
# Bulbasaur              1.0             1.0              2.0           1.0
# Ivysaur                1.0             1.0              2.0           1.0
# Venusaur               1.0             1.0              2.0           1.0
# Charmander             1.0             1.0              1.0           2.0
# Charmeleon             1.0             1.0              1.0           2.0
# ...                    ...             ...              ...           ...
# Celesteela             0.5             0.0              0.5           1.0
# Kartana                0.5             0.0              0.5           0.5
# Guzzlord               1.0             1.0              0.0           1.0
# Necrozma               1.0             1.0              0.5           1.0
# Magearna               0.5             0.0              0.5           0.5
#
#             against_steel  against_water  attack  base_happiness  base_total  \
# name
# Bulbasaur             1.0            0.5      49              70         318
# Ivysaur               1.0            0.5      62              70         405
# Venusaur              1.0            0.5     100              70         625
# Charmander            0.5            2.0      52              70         309
# Charmeleon            0.5            2.0      64              70         405
# ...                   ...            ...     ...             ...         ...
# Celesteela            0.5            1.0     101               0         570
# Kartana               0.5            0.5     181               0         570
# Guzzlord              1.0            0.5     101               0         570
# Necrozma              1.0            1.0     107               0         600
# Magearna              1.0            1.0      95               0         600
#
#             defense  height_m   hp  sp_attack  sp_defense  speed  weight_kg  \
# name
# Bulbasaur        49       0.7   45         65          65     45        6.9
# Ivysaur          63       1.0   60         80          80     60       13.0
# Venusaur        123       2.0   80        122         120     80      100.0
# Charmander       43       0.6   39         60          50     65        8.5
# Charmeleon       58       1.1   58         80          65     80       19.0
# ...             ...       ...  ...        ...         ...    ...        ...
# Celesteela      103       9.2   97        107         101     61      999.9
# Kartana         131       0.3   59         59          31    109        0.1
# Guzzlord         53       5.5  223         97          53     43      888.0
# Necrozma        101       2.4   97        127          89     79      230.0
# Magearna        115       1.0   80        130         115     65       80.5
#
#             is_legendary  type1_bug  type1_dark  type1_dragon  type1_electric  \
# name
# Bulbasaur              0          0           0             0               0
# Ivysaur                0          0           0             0               0
# Venusaur               0          0           0             0               0
# Charmander             0          0           0             0               0
# Charmeleon             0          0           0             0               0
# ...                  ...        ...         ...           ...             ...
# Celesteela             1          0           0             0               0
# Kartana                1          0           0             0               0
# Guzzlord               1          0           1             0               0
# Necrozma               1          0           0             0               0
# Magearna               1          0           0             0               0
#
#             type1_fairy  type1_fighting  type1_fire  type1_flying  \
# name
# Bulbasaur             0               0           0             0
# Ivysaur               0               0           0             0
# Venusaur              0               0           0             0
# Charmander            0               0           1             0
# Charmeleon            0               0           1             0
# ...                 ...             ...         ...           ...
# Celesteela            0               0           0             0
# Kartana               0               0           0             0
# Guzzlord              0               0           0             0
# Necrozma              0               0           0             0
# Magearna              0               0           0             0
#
#             type1_ghost  type1_grass  type1_ground  type1_ice  type1_normal  \
# name
# Bulbasaur             0            1             0          0             0
# Ivysaur               0            1             0          0             0
# Venusaur              0            1             0          0             0
# Charmander            0            0             0          0             0
# Charmeleon            0            0             0          0             0
# ...                 ...          ...           ...        ...           ...
# Celesteela            0            0             0          0             0
# Kartana               0            1             0          0             0
# Guzzlord              0            0             0          0             0
# Necrozma              0            0             0          0             0
# Magearna              0            0             0          0             0
#
#             type1_poison  type1_psychic  type1_rock  type1_steel  type1_water  \
# name
# Bulbasaur              0              0           0            0            0
# Ivysaur                0              0           0            0            0
# Venusaur               0              0           0            0            0
# Charmander             0              0           0            0            0
# Charmeleon             0              0           0            0            0
# ...                  ...            ...         ...          ...          ...
# Celesteela             0              0           0            1            0
# Kartana                0              0           0            0            0
# Guzzlord               0              0           0            0            0
# Necrozma               0              1           0            0            0
# Magearna               0              0           0            1            0
#
#             type2_bug  type2_dark  type2_dragon  type2_electric  type2_fairy  \
# name
# Bulbasaur           0           0             0               0            0
# Ivysaur             0           0             0               0            0
# Venusaur            0           0             0               0            0
# Charmander          0           0             0               0            0
# Charmeleon          0           0             0               0            0
# ...               ...         ...           ...             ...          ...
# Celesteela          0           0             0               0            0
# Kartana             0           0             0               0            0
# Guzzlord            0           0             1               0            0
# Necrozma            0           0             0               0            0
# Magearna            0           0             0               0            1
#
#             type2_fighting  type2_fire  type2_flying  type2_ghost  \
# name
# Bulbasaur                0           0             0            0
# Ivysaur                  0           0             0            0
# Venusaur                 0           0             0            0
# Charmander               0           0             0            0
# Charmeleon               0           0             0            0
# ...                    ...         ...           ...          ...
# Celesteela               0           0             1            0
# Kartana                  0           0             0            0
# Guzzlord                 0           0             0            0
# Necrozma                 0           0             0            0
# Magearna                 0           0             0            0
#
#             type2_grass  type2_ground  type2_ice  type2_none  type2_normal  \
# name
# Bulbasaur             0             0          0           0             0
# Ivysaur               0             0          0           0             0
# Venusaur              0             0          0           0             0
# Charmander            0             0          0           1             0
# Charmeleon            0             0          0           1             0
# ...                 ...           ...        ...         ...           ...
# Celesteela            0             0          0           0             0
# Kartana               0             0          0           0             0
# Guzzlord              0             0          0           0             0
# Necrozma              0             0          0           1             0
# Magearna              0             0          0           0             0
#
#             type2_poison  type2_psychic  type2_rock  type2_steel  type2_water  \
# name
# Bulbasaur              1              0           0            0            0
# Ivysaur                1              0           0            0            0
# Venusaur               1              0           0            0            0
# Charmander             0              0           0            0            0
# Charmeleon             0              0           0            0            0
# ...                  ...            ...         ...          ...          ...
# Celesteela             0              0           0            0            0
# Kartana                0              0           0            1            0
# Guzzlord               0              0           0            0            0
# Necrozma               0              0           0            0            0
# Magearna               0              0           0            0            0
#
#             capture_rate_bin_0-0.5  capture_rate_bin_0.5-1  \
# name
# Bulbasaur                        1                       0
# Ivysaur                          1                       0
# Venusaur                         1                       0
# Charmander                       1                       0
# Charmeleon                       1                       0
# ...                            ...                     ...
# Celesteela                       1                       0
# Kartana                          0                       0
# Guzzlord                         1                       0
# Necrozma                         1                       0
# Magearna                         1                       0
#
#             capture_rate_bin_1-1.5  capture_rate_bin_1.5-2.0  \
# name
# Bulbasaur                        0                         0
# Ivysaur                          0                         0
# Venusaur                         0                         0
# Charmander                       0                         0
# Charmeleon                       0                         0
# ...                            ...                       ...
# Celesteela                       0                         0
# Kartana                          0                         0
# Guzzlord                         0                         0
# Necrozma                         0                         0
# Magearna                         0                         0
#
#             capture_rate_bin_2.0-2.5  capture_rate_bin_2.5+  \
# name
# Bulbasaur                          0                      0
# Ivysaur                            0                      0
# Venusaur                           0                      0
# Charmander                         0                      0
# Charmeleon                         0                      0
# ...                              ...                    ...
# Celesteela                         0                      0
# Kartana                            0                      1
# Guzzlord                           0                      0
# Necrozma                           0                      0
# Magearna                           0                      0
#
#             experience_growth_bin_Above 1.1M  experience_growth_bin_Below 1.1M
# name
# Bulbasaur                                  0                                 1
# Ivysaur                                    0                                 1
# Venusaur                                   0                                 1
# Charmander                                 0                                 1
# Charmeleon                                 0                                 1
# ...                                      ...                               ...
# Celesteela                                 1                                 0
# Kartana                                    1                                 0
# Guzzlord                                   1                                 0
# Necrozma                                   1                                 0
# Magearna                                   1                                 0
#
# [801 rows x 74 columns]

# %%
X, y = df.drop(['is_legendary','is_legendary','against_bug', 'against_dark', 'against_dragon', 'against_electric',
       'against_fairy', 'against_fight', 'against_fire', 'against_flying',
       'against_ghost', 'against_grass', 'against_ground', 'against_ice',
       'against_normal', 'against_poison', 'against_psychic', 'against_rock',
       'against_steel', 'against_water', 'height_m', 'weight_kg', 'capture_rate_bin_0-0.5', 'capture_rate_bin_0.5-1',
       'capture_rate_bin_1-1.5', 'capture_rate_bin_1.5-2.0',
       'capture_rate_bin_2.0-2.5', 'capture_rate_bin_2.5+',
       'experience_growth_bin_Above 1.1M', 'experience_growth_bin_Below 1.1M','base_happiness', 'type2_electric', 'type2_fighting', 'type2_flying', 'type2_ground' ], axis = 1), df['is_legendary']
train_X, test_X, train_y, test_y = train_test_split(X, y, train_size = 0.7, test_size = 0.3, stratify = y)
y.value_counts()
# Out:
# 0    731
# 1     70
# Name: is_legendary, dtype: int64

# %%
len(X.columns)
# Out:
# 40

# %% [markdown]
# ### Uploading Inference

# %%
inf_test = pd.read_csv('pokemon_inf.csv')

# %%
inf_test.head(3)
# Out:
#         name  type1 type2   hp  attack  defense  sp_attack  sp_defense  speed  \
# 0    Grookey  Grass   NaN   50      65       50         40          40     65
# 1   Thwackey  Grass   NaN   70      85       70         55          60     80
# 2  Rillaboom  Grass   NaN  100     125       90         60          70     85
#
#    base_total  legendary
# 0         310          0
# 1         420          0
# 2         530          0

# %%
inf_test.dtypes
# Out:
# name          object
# type1         object
# type2         object
# hp             int64
# attack         int64
# defense        int64
# sp_attack      int64
# sp_defense     int64
# speed          int64
# base_total     int64
# legendary      int64
# dtype: object

# %%
inf_test.isnull().sum()
# Out:
# name           0
# type1          0
# type2         53
# hp             0
# attack         0
# defense        0
# sp_attack      0
# sp_defense     0
# speed          0
# base_total     0
# legendary      0
# dtype: int64

# %%
inf_test['type2'] = inf_test['type2'].fillna('none')

# %%
inf_test['type1'] = inf_test['type1'].str.lower()

# %%
inf_test['type2'] = inf_test['type2'].str.lower()

# %%
inf_test = inf_test.set_index('name')
inf_test.head()
# Out:
#            type1 type2   hp  attack  defense  sp_attack  sp_defense  speed  \
# name
# Grookey    grass  none   50      65       50         40          40     65
# Thwackey   grass  none   70      85       70         55          60     80
# Rillaboom  grass  none  100     125       90         60          70     85
# Scorbunny   fire  none   50      71       40         40          40     69
# Raboot      fire  none   65      86       60         55          60     94
#
#            base_total  legendary
# name
# Grookey           310          0
# Thwackey          420          0
# Rillaboom         530          0
# Scorbunny         310          0
# Raboot            420          0

# %%
inf_test_dum = pd.get_dummies(inf_test)

# %%
inf_X, inf_y = inf_test_dum.drop(['legendary'], axis = 1), inf_test_dum['legendary']

# %%
len(inf_X.columns)
# Out:
# 40

# %% [markdown]
# # Oversampling

# %%
g = sns.countplot(df['is_legendary'])
g.set_xticklabels(['not_legendary','legendary'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'not_legendary'), Text(1, 0, 'legendary')]

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(sampling_strategy = 0.8,random_state=42,k_neighbors=20)
x_train_res, y_train_res = sm.fit_resample(train_X, train_y)

# %%
y_train_res.value_counts()
# Out:
# 0    511
# 1    408
# Name: is_legendary, dtype: int64

# %% [markdown]
# # Traning Models

# %%
#define functions for classifiers

from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")
def classifier(model):
    
    clf = model
    clf.fit(x_train_res, y_train_res)
    y_pred = clf.predict(inf_X)
    
    kf=KFold(n_splits=5)
    cv_score=cross_val_score(clf,x_train_res,y_train_res,cv=kf)
    acc_score = accuracy_score(inf_y, y_pred)
    
    print("Cross Validation Scores are {}".format(cv_score))
    print("Average Cross Validation score :{}".format(cv_score.mean()))
    #print(confusion_matrix(test_y, y_pred))
    print(classification_report(inf_y, y_pred))
    print("accuracy: ", acc_score)
    return clf, acc_score, cv_score.mean()

# %%
#define functions for comparing RMSE

from sklearn.metrics import mean_squared_error 
from sklearn.model_selection import cross_val_score

def compare_RMSE(model,x_train_res,y_train_res,inf_X,inf_y):
    
    # test
    test_rmse = mean_squared_error(inf_y, model.predict(inf_X), squared=False)
    print(f"Test set RMSE:", test_rmse)

    # cv
    MSE_CV_scores = - cross_val_score(model, x_train_res, y_train_res, cv=10, 
                                      scoring='neg_mean_squared_error', 
                                      n_jobs=-1) 
    RMSE_CV = (MSE_CV_scores.mean())**(1/2)
    print(f"CV RMSE:", RMSE_CV)

    # train
    RMSE_train = (mean_squared_error(y_train_res, model.predict(x_train_res)))**(1/2)
    print(f"Training set RMSE:",RMSE_train)

# %%
#define functions for confusion matrix
from sklearn import metrics
import matplotlib.pyplot as plt

def draw_confusion_matrix(model,inf_X,inf_y):

    cnf_matrix = metrics.confusion_matrix(inf_y, model.predict(inf_X))
    # create heatmap
    fig, ax = plt.subplots()

    sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### logistic regression

# %%
#logistic regression

logistic_regression, acc_log_reg,log_mean_cv_score = classifier(LogisticRegression(max_iter = 1000))
# Out:
# Cross Validation Scores are [0.91847826 0.95652174 0.94565217 0.98369565 0.99453552]
# Average Cross Validation score :0.959776669042528
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        82
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.83        99
#    macro avg       0.41      0.50      0.45        99
# weighted avg       0.69      0.83      0.75        99
#
# accuracy:  0.8282828282828283

# %%
draw_confusion_matrix(logistic_regression,inf_X,inf_y)

# %%
roc_curve(inf_y, logistic_regression.predict(inf_X))
# Out:
# (array([0., 1.]), array([0., 1.]), array([1, 0]))

# %%
y_pred_proba = logistic_regression.predict_proba(inf_X)[::,1]
fpr, tpr, _ = metrics.roc_curve(inf_y,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

print('roc score:',roc_auc_score(inf_y,y_pred_proba))
# Out:
# roc score: 0.4878048780487805

# %%
compare_RMSE(logistic_regression,x_train_res, y_train_res,inf_X,inf_y)
# Out:
# Test set RMSE: 0.41438770700537403
# CV RMSE: 0.21621996904066143
# Training set RMSE: 0.16820113355007427

# %% [markdown]
# ### random forest

# %%
#random forest
random_forest, acc_random_forest,rf_mean_cv_score = classifier(RandomForestClassifier(n_estimators = 1000, max_depth = 5,  max_features = 10))
# Out:
# Cross Validation Scores are [0.91847826 0.95652174 0.95652174 0.97826087 0.99453552]
# Average Cross Validation score :0.9608636255642671
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        82
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.83        99
#    macro avg       0.41      0.50      0.45        99
# weighted avg       0.69      0.83      0.75        99
#
# accuracy:  0.8282828282828283

# %%
draw_confusion_matrix(random_forest,inf_X,inf_y)

# %%
compare_RMSE(random_forest,x_train_res, y_train_res,inf_X,inf_y)
# Out:
# Test set RMSE: 0.41438770700537403
# CV RMSE: 0.19233396858229784
# Training set RMSE: 0.16160242189977778

# %%
importances = random_forest.feature_importances_
std = np.std([random_forest.feature_importances_ for tree in random_forest.estimators_], axis=0)

# %%
forest_importances = pd.Series(importances, index=train_X.columns)
forest_importances = forest_importances.sort_values(ascending=False)
forest_importances = forest_importances[:20]
fig, ax = plt.subplots()

forest_importances.plot.bar(yerr=std[:20], ax=ax,figsize=(12, 6))
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %% [markdown]
# ### SGD

# %%
#SGD
SGD, acc_sgd,SGD_mean_cv_score = classifier(SGDClassifier())
# Out:
# Cross Validation Scores are [0.40217391 0.17391304 0.10869565 0.95108696 0.77595628]
# Average Cross Validation score :0.4823651698740793
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        82
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.83        99
#    macro avg       0.41      0.50      0.45        99
# weighted avg       0.69      0.83      0.75        99
#
# accuracy:  0.8282828282828283

# %%
draw_confusion_matrix(SGD,inf_X,inf_y)

# %%
# Evaluate the model by comparing three RMSE's.
compare_RMSE(SGD,x_train_res, y_train_res,inf_X,inf_y)
# Out:
# Test set RMSE: 0.41438770700537403
# CV RMSE: 0.6950614130369895
# Training set RMSE: 0.5873160583020861

# %% [markdown]
# ### decision tree

# %%
#decision tree
decision_tree, acc_decision_tree, decision_tree_mean_cv_score= classifier(DecisionTreeClassifier())
# Out:
# Cross Validation Scores are [0.9673913  0.95108696 0.98369565 0.96195652 0.98360656]
# Average Cross Validation score :0.9695473984319316
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       220
#            1       0.77      0.81      0.79        21
#
#     accuracy                           0.96       241
#    macro avg       0.88      0.89      0.89       241
# weighted avg       0.96      0.96      0.96       241
#
# accuracy:  0.9626556016597511

# %%
draw_confusion_matrix(decision_tree,test_X,test_y)

# %%
compare_RMSE(decision_tree,x_train_res, y_train_res,test_X,test_y)
# Out:
# Test set RMSE: 0.19324698792024925
# CV RMSE: 0.16825173958644607
# Training set RMSE: 0.0

# %% [markdown]
# ### SVC

# %%
#Linear SVC
linear_SVC, acc_linear_svc,linear_SVC_mean_cv_score = classifier(LinearSVC(max_iter = 100))
# Out:
# Cross Validation Scores are [0.9076087  0.94565217 0.98369565 0.09782609 0.68306011]
# Average Cross Validation score :0.723568543597054
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96       220
#            1       1.00      0.14      0.25        21
#
#     accuracy                           0.93       241
#    macro avg       0.96      0.57      0.61       241
# weighted avg       0.93      0.93      0.90       241
#
# accuracy:  0.9253112033195021

# %%
draw_confusion_matrix(linear_SVC,test_X,test_y)

# %%
compare_RMSE(linear_SVC,x_train_res, y_train_res,test_X,test_y)
# Out:
# Test set RMSE: 0.27329251120456616
# CV RMSE: 0.437465444679987
# Training set RMSE: 0.6258834887246241

# %% [markdown]
# ### GaussianNB

# %%
#GaussianNB
gaussian_NB, acc_gnb,gaussian_NB_mean_cv_score = classifier(GaussianNB())
# Out:
# Cross Validation Scores are [0.88043478 0.96195652 0.92934783 0.97826087 1.        ]
# Average Cross Validation score :0.95
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       220
#            1       0.75      0.57      0.65        21
#
#     accuracy                           0.95       241
#    macro avg       0.85      0.78      0.81       241
# weighted avg       0.94      0.95      0.94       241
#
# accuracy:  0.946058091286307

# %%
draw_confusion_matrix(gaussian_NB,test_X,test_y)

# %%
compare_RMSE(gaussian_NB,x_train_res, y_train_res,test_X,test_y)
# Out:
# Test set RMSE: 0.23225397459180963
# CV RMSE: 0.2308349165952615
# Training set RMSE: 0.2033452549470157

# %% [markdown]
# ### KNeighbors Classifier

# %%
#KNeighbors Classifier
kneighbors, acc_knn,kneighbors_mean_cv_score = classifier(KNeighborsClassifier())
# Out:
# Cross Validation Scores are [0.95108696 0.89130435 0.95652174 0.98369565 0.98360656]
# Average Cross Validation score :0.9532430506058447
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       220
#            1       0.64      1.00      0.78        21
#
#     accuracy                           0.95       241
#    macro avg       0.82      0.97      0.87       241
# weighted avg       0.97      0.95      0.96       241
#
# accuracy:  0.950207468879668

# %%
draw_confusion_matrix(kneighbors,test_X,test_y)

# %%
compare_RMSE(kneighbors,x_train_res, y_train_res,test_X,test_y)
# Out:
# Test set RMSE: 0.22314240099168053
# CV RMSE: 0.21371958980722242
# Training set RMSE: 0.1923453549794081

# %% [markdown]
# ### Perceptron

# %%
#Perceptron
perceptron, acc_perceptron,perceptron_mean_cv_score = classifier(Perceptron())
# Out:
# Cross Validation Scores are [0.53804348 0.85869565 0.71195652 0.69565217 0.91803279]
# Average Cross Validation score :0.7444761225944405
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91       220
#            1       0.31      0.71      0.43        21
#
#     accuracy                           0.84       241
#    macro avg       0.64      0.78      0.67       241
# weighted avg       0.91      0.84      0.86       241
#
# accuracy:  0.8381742738589212

# %%
draw_confusion_matrix(perceptron,test_X,test_y)

# %%
compare_RMSE(perceptron,x_train_res, y_train_res,test_X,test_y)
# Out:
# Test set RMSE: 0.40227568425282534
# CV RMSE: 0.4362761018849961
# Training set RMSE: 0.4066905098940314

# %% [markdown]
# ### All Model Accuracy

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Linear SVC', 
              'KNN', 'Decision Tree', 'Random Forest', 'Gaussain Naive Bayes', 
              'Perceptron', 'Stochastic Gradient Descent'],
    
    'Score': [acc_log_reg, acc_linear_svc, 
              acc_knn,  acc_decision_tree, acc_random_forest, acc_gnb, 
              acc_perceptron, acc_sgd],
    
     'Average CV score': [log_mean_cv_score, linear_SVC_mean_cv_score, 
              kneighbors_mean_cv_score,  decision_tree_mean_cv_score, rf_mean_cv_score, gaussian_NB_mean_cv_score, 
              perceptron_mean_cv_score, SGD_mean_cv_score]   
    
    })

models.sort_values(by='Score', ascending=False)
# Out:
#                          Model     Score  Average CV score
# 0          Logistic Regression  0.983402          0.970652
# 4                Random Forest  0.979253          0.977156
# 3                Decision Tree  0.962656          0.969547
# 2                          KNN  0.950207          0.953243
# 5         Gaussain Naive Bayes  0.946058          0.950000
# 1                   Linear SVC  0.925311          0.723569
# 7  Stochastic Gradient Descent  0.854772          0.737420
# 6                   Perceptron  0.838174          0.744476
